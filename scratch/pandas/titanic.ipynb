# %%
import pandas

# %%
dir(pandas)
# Out:
# ['Categorical',
#  'DataFrame',
#  'DateOffset',
#  'DateRange',
#  'DatetimeIndex',
#  'ExcelFile',
#  'ExcelWriter',
#  'Factor',
#  'HDFStore',
#  'Index',
#  'Int64Index',
#  'MultiIndex',
#  'NaT',
#  'Panel',
#  'Panel4D',
#  'Period',
#  'PeriodIndex',
#  'Series',
#  'SparseArray',
#  'SparseDataFrame',
#  'SparseList',
#  'SparsePanel',
#  'SparseSeries',
#  'SparseTimeSeries',
#  'Term',
#  'TimeGrouper',
#  'TimeSeries',
#  'Timestamp',
#  'WidePanel',
#  '__builtins__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__version__',
#  '_sparse',
#  'algos',
#  'bdate_range',
#  'compat',
#  'concat',
#  'core',
#  'crosstab',
#  'cut',
#  'date_range',
#  'datetime',
#  'datetools',
#  'debug',
#  'describe_option',
#  'ewma',
#  'ewmcorr',
#  'ewmcov',
#  'ewmstd',
#  'ewmvar',
#  'ewmvol',
#  'expanding_apply',
#  'expanding_corr',
#  'expanding_corr_pairwise',
#  'expanding_count',
#  'expanding_cov',
# ...
